# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tanmayshukla28/Flyrank-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I selected the Website Performance lane because website speed and page performance directly affect user experience and search rankings. Slow-loading pages can reduce user engagement and organic traffic. I want to explore how performance-related metrics can help identify pages that should be optimized first.

# %%
print("Website Performance lane selected")
# Out:
# Website Performance lane selected

# %% [markdown]
# ## Research Question
#
# Decision:
# Which web pages should the team optimize first to improve website performance?
#
# Action:
# The SEO or engineering team will optimize the selected pages by improving loading speed, reducing page size, or updating content.
#
# Cost of a Wrong Recommendation:
# If the wrong pages are selected, time and engineering effort will be wasted while important slow pages remain unoptimized, which can reduce user satisfaction and search performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("Research question documented.")
# Out:
# Research question documented.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !pwd
# !ls
# !find . -name "*.csv"
# Out:
# /content
# sample_data
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# I attempted to load the starter dataset, but it was not available in the current notebook environment. I verified the working directory and available files before proceeding. Once the starter dataset is available, I will report real dataset statistics such as the number of pages and summary metrics relevant to the Website Performance lane.

# %%
import os

print("Current working directory:", os.getcwd())
print("Files available:", os.listdir())
# Out:
# Current working directory: /content
# Files available: ['.config', 'sample_data']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work is intended to support decisions about which website pages should be prioritized for optimization based on available data. It cannot guarantee higher Google rankings or prove that improving a single metric will always increase traffic. The analysis is meant to assist decision-making rather than provide certainty.

# %%
print("Claims documented.")
# Out:
# Claims documented.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
